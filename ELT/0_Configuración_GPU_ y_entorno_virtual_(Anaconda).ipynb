# %% [markdown]
# <img src="https://www.unir.net/wp-content/uploads/2019/11/Unir_2021_logo.svg" width="240" height="240" align="right"/>

# %% [markdown]
# <h2>Deep Learning en el diagnóstico de Alzheimer mediante Imágenes de Resonancia Magnética</h2>

# %% [markdown]
# ### Configuración de GPU y entorno virtual (Anaconda)

# %% [markdown]
# <b>Instrucciones</b>
#
# jupyter notebook --notebook-dir=D:/
#
# cd "/Volumes/My Book"
# jupyter notebook
#
# Abrir Anaconda prompt
#
# conda create -n gpu_tfm python=3.7
# conda activate gpu_tfm
# pip install tensorflow-directml
#
# import tensorflow as tf
# tf.test.is_gpu_available()
# print("Num GPUs available", len(tf.config.experimental.list_physical_devices('GPU')))
#
# pip install ipykernel
# python -m ipykernel install --user --name gpu_tfm --display-name "gpu_tfm"
#
# import tensorflow as tf
# tf.test.is_gpu_available()
# print("Num GPUs available", len(tf.config.experimental.list_physical_devices('GPU')))
#
# tf.test.gpu_device_name()
# tf.test.is_gpu_available()

# %% [markdown]
# ![image.png](attachment:image.png)
